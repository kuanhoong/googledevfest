# %% [markdown]
# # Transfer Learning for Classifying Cat and Dog images using Tensorflow

# %% [markdown]
# ## Introduction
#
# Modern object recognition models have millions of parameters and can take weeks to fully train. Transfer learning is a technique that shortcuts a lot of this work by taking a fully-trained model for a set of categories like ImageNet, and retrains from the existing weights for new classes.
#
# In this notebook, Google's Inception-V3 pretrained model for Image Classification will be used. Inception v3 is a trained for the [ImageNet](http://image-net.org/) Large Visual Recognition Challenge using the data from 2012, and it can differentiate between 1,000 different classes, like Dalmatian or dishwasher.
#
# The chart below shows how the data flows in the Inception v3 model, which is a Convolutional Neural Network with many layers and a complicated structure. The [research paper](http://arxiv.org/pdf/1512.00567v3.pdf) gives more details on how the Inception model is constructed and why it is designed that way.
#
# ![](./images/inception_flowchart.png)

# %% [markdown]
# Inception model is actually quite capable of extracting useful information from an image. So we can instead train the Inception model using another data-set, in for this notebook the Cat vs Dog dataset. But it takes several weeks using a very powerful and expensive computer to fully train the Inception model on a new data-set.
#
# We can instead re-use the pre-trained Inception model and merely replace the layer that does the final classification. This is called Transfer Learning.
#
# Though it's not as good as a full training run, this is surprisingly effective for many applications, and can be run in as little as thirty minutes on a laptop, without requiring a GPU.
#
# Transfer Learning will be used to retrain the last layers of the Inception model to be able to classify Cat and Dog images.
#
# ## Dataset
#
# Reference :<br>
# [Animals on the Web](http://tamaraberg.com/papers/berg_animals.pdf) <br>
# [Tamara L. Berg](http://tamaraberg.com/), [David A. Forsyth](http://luthuli.cs.uiuc.edu/~daf) <br>
# *Computer Vision and Pattern Recognition (CVPR), 2006* <br>
#
# Preprocessed dataset in the Github repository.  You may want to use other animal images for classification.

# %% [markdown]
# ## Data Preprocessing
#
# The postive samples saved in the directory may not be optimal for classifying using transfer learning on the Inception model. The Inception model was trained on the ImageNet dataset which contains JPG / JPEG images sized **299 X 299**. Our positive samples contains some GIFs and other images in PNG format. Hence there is a need to preprocess the dataset.

# %% [markdown]
# ### gifs2jpg.py

# %%
# convert gif to jpg
from PIL import Image
import glob
import os,sys,shutil

def processImage(infile):
    try:
        im = Image.open(infile)
    except IOError:
        print("Cant load", infile)
        sys.exit(1)
    i = 0
    mypalette = im.getpalette()

    try:
        while 1:
            im.putpalette(mypalette)
            new_im = Image.new("RGBA", im.size)
            new_im.paste(im)
            infilename = os.path.splitext(infile)[0]
            new_im.save(infile+str(i)+'.jpg')
            print('Saved : ' + infilename+str(i)+'.jpg')
            i += 1
            im.seek(im.tell() + 1)

    except EOFError:
        pass # end of sequence

if False:   # Dont call this as the preprocessed dataset is already included.
            # Call this if you want to carry out the preprocessing yourself
    for single_gif in glob.glob('*.gif'):
        print(single_gif)
        processImage(single_gif)
        ensure_dir_exists('Converted_gifs')
        shutil.move(single_gif,'Converted_gifs/'+single_gif)

# %% [markdown]
# ### resizeImages.py

# %%
# resize image to 299 X 299
import os, sys, glob
from PIL import Image

size = (299, 299)
filetypes =['*.jpg','*.jpeg']

def resize(infile):
    outfile = os.path.splitext(infile)[0] + "_resized.jpg"
    if infile != outfile:
        try:
            im = Image.open(infile)
            im.thumbnail(size, Image.ANTIALIAS)
            old_im_size = im.size
            
            ## By default, black colour would be used as the background for padding!
            new_im = Image.new("RGB", size)

            new_im.paste(im, (int((size[0]-old_im_size[0])/2),int((size[1]-old_im_size[1])/2)))
            
            new_im.save('Resized_JPGs/' + outfile, "JPEG")
        except IOError:
            print ("Cannot resize '%s'" % infile)

if False:   # Dont call this as the preprocessed dataset is already included.
            # Call this if you want to carry out the preprocessing yourself            
    for filetype in filetypes:
        for single_jpg in glob.glob(filetype):
            print (single_jpg)
            resize(single_jpg)

    print ("Done")

# %% [markdown]
# This script resizes the images to 299 x 299 by padding black color to the boundaries.
#
# For example it resizes
#
# <img src="images/original.jpg">
#
# to :
#
# <img src="images/resized.jpg">

# %% [markdown]
# Now that we have our datasets ready we can move over to actually code our image classifier.

# %% [markdown]
# # Retraining

# %% [markdown]
# The following scripts demonstrate how to take an Inception v3 architecture model trained on
# ImageNet images, and train a new top layer that can recognize other classes of
# images.
#
# The top layer receives as input a 2048-dimensional vector for each image. We
# train a softmax layer on top of this representation. Assuming the softmax layer
# contains N labels, this corresponds to learning N + 2048*N model parameters
# corresponding to the learned biases and weights.
#
# We have a folder called Animals_Data containing class-named
# subfolders of 'Leopard' and 'Giraffe', each containing full of images for Leopards and Giraffes.
# The subfolder names are important, since they define what label is applied to
# each image, but the filenames themselves don't matter. The label for each image is taken from the name of the subfolder it's
# in. This produces a new model file that can be loaded and run by any TensorFlow
# program, for example the label_image sample code.

# %% [markdown]
# ## Imports

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from datetime import datetime
import hashlib
import os.path
import random
import re
import struct
import sys
import tarfile

import numpy as np
from six.moves import urllib
import tensorflow as tf

from tensorflow.python.framework import graph_util
from tensorflow.python.framework import tensor_shape
from tensorflow.python.platform import gfile
from tensorflow.python.util import compat

# %% [markdown]
# The following are all parameters that are tied to the particular model architecture
# we're using for Inception v3. These include things like tensor names and their
# sizes. If you want to adapt this script to work with another model, you will
# need to update these to reflect the values in the network you're using.

# %%
import os
image_dir = os.path.join("Animal_Data")
output_graph = "output_graph.pb"
output_labels = "output_labels.txt"
summaries_dir = "/Users/user_adax/github/google_io_extended_KL/temp/"
how_many_training_steps = 4000
learning_rate = 0.01
testing_percentage = 10
validation_percentage = 10
eval_step_interval = 10
train_batch_size = 100
test_batch_size = -1
validation_batch_size = 100
print_misclassified_test_images = False
model_dir = os.path.join('inception')
bottleneck_dir = "bottlenecks"
final_tensor_name = "final_result"
flip_left_right = False
random_crop = 0
random_scale = 0
random_brightness = 0
DATA_URL = 'http://download.tensorflow.org/models/image/imagenet/inception-2015-12-05.tgz'

# pylint: enable=line-too-long
BOTTLENECK_TENSOR_NAME = 'pool_3/_reshape:0'
BOTTLENECK_TENSOR_SIZE = 2048
MODEL_INPUT_WIDTH = 299
MODEL_INPUT_HEIGHT = 299
MODEL_INPUT_DEPTH = 3
JPEG_DATA_TENSOR_NAME = 'DecodeJpeg/contents:0'
RESIZED_INPUT_TENSOR_NAME = 'ResizeBilinear:0'
MAX_NUM_IMAGES_PER_CLASS = 2 ** 27 - 1  # ~134M

# %%
def create_image_lists(image_dir, testing_percentage, validation_percentage):
  if not gfile.Exists(image_dir):
    print("Image directory '" + image_dir + "' not found.")
    return None
  result = {}
  sub_dirs = [x[0] for x in gfile.Walk(image_dir)]
  # The root directory comes first, so skip it.
  is_root_dir = True
  for sub_dir in sub_dirs:
    if is_root_dir:
      is_root_dir = False
      continue
    extensions = ['jpg', 'jpeg', 'JPG', 'JPEG']
    file_list = []
    dir_name = os.path.basename(sub_dir)
    if dir_name == image_dir:
      continue
    print("Looking for images in '" + dir_name + "'")
    for extension in extensions:
      file_glob = os.path.join(image_dir, dir_name, '*.' + extension)
      file_list.extend(gfile.Glob(file_glob))
    if not file_list:
      print('No files found')
      continue
    if len(file_list) < 20:
      print('WARNING: Folder has less than 20 images, which may cause issues.')
    elif len(file_list) > MAX_NUM_IMAGES_PER_CLASS:
      print('WARNING: Folder {} has more than {} images. Some images will '
            'never be selected.'.format(dir_name, MAX_NUM_IMAGES_PER_CLASS))
    label_name = re.sub(r'[^a-z0-9]+', ' ', dir_name.lower())
    training_images = []
    testing_images = []
    validation_images = []
    for file_name in file_list:
      base_name = os.path.basename(file_name)
      # We want to ignore anything after '_nohash_' in the file name when
      # deciding which set to put an image in, the data set creator has a way of
      # grouping photos that are close variations of each other. For example
      # this is used in the plant disease data set to group multiple pictures of
      # the same leaf.
      hash_name = re.sub(r'_nohash_.*$', '', file_name)
      # This looks a bit magical, but we need to decide whether this file should
      # go into the training, testing, or validation sets, and we want to keep
      # existing files in the same set even if more files are subsequently
      # added.
      # To do that, we need a stable way of deciding based on just the file name
      # itself, so we do a hash of that and then use that to generate a
      # probability value that we use to assign it.
      hash_name_hashed = hashlib.sha1(compat.as_bytes(hash_name)).hexdigest()
      percentage_hash = ((int(hash_name_hashed, 16) %
                          (MAX_NUM_IMAGES_PER_CLASS + 1)) *
                         (100.0 / MAX_NUM_IMAGES_PER_CLASS))
      if percentage_hash < validation_percentage:
        validation_images.append(base_name)
      elif percentage_hash < (testing_percentage + validation_percentage):
        testing_images.append(base_name)
      else:
        training_images.append(base_name)
    result[label_name] = {
        'dir': dir_name,
        'training': training_images,
        'testing': testing_images,
        'validation': validation_images,
    }
  return result

# %%
# function returns a path to an image for a label at the given index
def get_image_path(image_lists, label_name, index, image_dir, category):
  if label_name not in image_lists:
    tf.logging.fatal('Label does not exist %s.', label_name)
  label_lists = image_lists[label_name]
  if category not in label_lists:
    tf.logging.fatal('Category does not exist %s.', category)
  category_list = label_lists[category]
  if not category_list:
    tf.logging.fatal('Label %s has no images in the category %s.',
                     label_name, category)
  mod_index = index % len(category_list)
  base_name = category_list[mod_index]
  sub_dir = label_lists['dir']
  full_path = os.path.join(image_dir, sub_dir, base_name)
  return full_path

# %%
# returns a path to a bottleneck file for a label at the given index
def get_bottleneck_path(image_lists, label_name, index, bottleneck_dir,
                        category):
  
  return get_image_path(image_lists, label_name, index, bottleneck_dir,
                        category) + '.txt'

# %%
# create a graph from saved GraphDef file and returns a Graph object
def create_inception_graph():
  with tf.Session() as sess:
    model_filename = os.path.join(
        model_dir, 'classify_image_graph_def.pb')
    with gfile.FastGFile(model_filename, 'rb') as f:
      graph_def = tf.GraphDef()
      graph_def.ParseFromString(f.read())
      bottleneck_tensor, jpeg_data_tensor, resized_input_tensor = (
          tf.import_graph_def(graph_def, name='', return_elements=[
              BOTTLENECK_TENSOR_NAME, JPEG_DATA_TENSOR_NAME,
              RESIZED_INPUT_TENSOR_NAME]))
  return sess.graph, bottleneck_tensor, jpeg_data_tensor, resized_input_tensor

# %%
# inference on an image to extract the 'bottleneck' summary layer.
def run_bottleneck_on_image(sess, image_data, image_data_tensor,
                            bottleneck_tensor):
  bottleneck_values = sess.run(
      bottleneck_tensor,
      {image_data_tensor: image_data})
  bottleneck_values = np.squeeze(bottleneck_values)
  return bottleneck_values

# %%
# downloads and extracts model tar file
def maybe_download_and_extract():
  dest_directory = model_dir
  if not os.path.exists(dest_directory):
    os.makedirs(dest_directory)
  filename = DATA_URL.split('/')[-1]
  filepath = os.path.join(dest_directory, filename)
  if not os.path.exists(filepath):

    def _progress(count, block_size, total_size):
      sys.stdout.write('\r>> Downloading %s %.1f%%' %
                       (filename,
                        float(count * block_size) / float(total_size) * 100.0))
      sys.stdout.flush()

    filepath, _ = urllib.request.urlretrieve(DATA_URL,
                                             filepath,
                                             _progress)
    print()
    statinfo = os.stat(filepath)
    print('Successfully downloaded', filename, statinfo.st_size, 'bytes.')
  tarfile.open(filepath, 'r:gz').extractall(dest_directory)

# %%
# make sure the folder exists on disk
def ensure_dir_exists(dir_name):
  if not os.path.exists(dir_name):
    os.makedirs(dir_name)

# %%
# write a given list of floats to a binary file
def write_list_of_floats_to_file(list_of_floats , file_path):
  s = struct.pack('d' * BOTTLENECK_TENSOR_SIZE, *list_of_floats)
  with open(file_path, 'wb') as f:
    f.write(s)

# %%
# read list of floats from a given file
def read_list_of_floats_from_file(file_path):

  with open(file_path, 'rb') as f:
    s = struct.unpack('d' * BOTTLENECK_TENSOR_SIZE, f.read())
    return list(s)

# %%
bottleneck_path_2_bottleneck_values = {}

def create_bottleneck_file(bottleneck_path, image_lists, label_name, index,
                           image_dir, category, sess, jpeg_data_tensor, bottleneck_tensor):
  print('Creating bottleneck at ' + bottleneck_path)
  image_path = get_image_path(image_lists, label_name, index, image_dir, category)
  if not gfile.Exists(image_path):
    tf.logging.fatal('File does not exist %s', image_path)
  image_data = gfile.FastGFile(image_path, 'rb').read()
  bottleneck_values = run_bottleneck_on_image(sess, image_data, jpeg_data_tensor, bottleneck_tensor)
  bottleneck_string = ','.join(str(x) for x in bottleneck_values)
  with open(bottleneck_path, 'w') as bottleneck_file:
    bottleneck_file.write(bottleneck_string)

# %%
# retrieves or calculates bottleneck values for an image.
def get_or_create_bottleneck(sess, image_lists, label_name, index, image_dir,
                             category, bottleneck_dir, jpeg_data_tensor,
                             bottleneck_tensor):
  label_lists = image_lists[label_name]
  sub_dir = label_lists['dir']
  sub_dir_path = os.path.join(bottleneck_dir, sub_dir)
  ensure_dir_exists(sub_dir_path)
  bottleneck_path = get_bottleneck_path(image_lists, label_name, index, bottleneck_dir, category)
  if not os.path.exists(bottleneck_path):
    create_bottleneck_file(bottleneck_path, image_lists, label_name, index, image_dir, category, sess, jpeg_data_tensor, bottleneck_tensor)
  with open(bottleneck_path, 'r') as bottleneck_file:
    bottleneck_string = bottleneck_file.read()
  did_hit_error = False
  try:
    bottleneck_values = [float(x) for x in bottleneck_string.split(',')]
  except:
    print("Invalid float found, recreating bottleneck")
    did_hit_error = True
  if did_hit_error:
    create_bottleneck_file(bottleneck_path, image_lists, label_name, index, image_dir, category, sess, jpeg_data_tensor, bottleneck_tensor)
    with open(bottleneck_path, 'r') as bottleneck_file:
      bottleneck_string = bottleneck_file.read()
    # Allow exceptions to propagate here, since they shouldn't happen after a fresh creation
    bottleneck_values = [float(x) for x in bottleneck_string.split(',')]
  return bottleneck_values

# %%
# ensure all the training, testing, and validation bottlenecks are cached
def cache_bottlenecks(sess, image_lists, image_dir, bottleneck_dir,
                      jpeg_data_tensor, bottleneck_tensor):
  how_many_bottlenecks = 0
  ensure_dir_exists(bottleneck_dir)
  for label_name, label_lists in image_lists.items():
    for category in ['training', 'testing', 'validation']:
      category_list = label_lists[category]
      for index, unused_base_name in enumerate(category_list):
        get_or_create_bottleneck(sess, image_lists, label_name, index,
                                 image_dir, category, bottleneck_dir,
                                 jpeg_data_tensor, bottleneck_tensor)

        how_many_bottlenecks += 1
        if how_many_bottlenecks % 100 == 0:
          print(str(how_many_bottlenecks) + ' bottleneck files created.')

# %%
# retrieve bottleneck values for cached images
def get_random_cached_bottlenecks(sess, image_lists, how_many, category,
                                  bottleneck_dir, image_dir, jpeg_data_tensor,
                                  bottleneck_tensor):
  class_count = len(image_lists.keys())
  bottlenecks = []
  ground_truths = []
  filenames = []
  if how_many >= 0:
    # Retrieve a random sample of bottlenecks.
    for unused_i in range(how_many):
      label_index = random.randrange(class_count)
      label_name = list(image_lists.keys())[label_index]
      image_index = random.randrange(MAX_NUM_IMAGES_PER_CLASS + 1)
      image_name = get_image_path(image_lists, label_name, image_index,
                                  image_dir, category)
      bottleneck = get_or_create_bottleneck(sess, image_lists, label_name,
                                            image_index, image_dir, category,
                                            bottleneck_dir, jpeg_data_tensor,
                                            bottleneck_tensor)
      ground_truth = np.zeros(class_count, dtype=np.float32)
      ground_truth[label_index] = 1.0
      bottlenecks.append(bottleneck)
      ground_truths.append(ground_truth)
      filenames.append(image_name)
  else:
    # Retrieve all bottlenecks.
    for label_index, label_name in enumerate(image_lists.keys()):
      for image_index, image_name in enumerate(
          image_lists[label_name][category]):
        image_name = get_image_path(image_lists, label_name, image_index,
                                    image_dir, category)
        bottleneck = get_or_create_bottleneck(sess, image_lists, label_name,
                                              image_index, image_dir, category,
                                              bottleneck_dir, jpeg_data_tensor,
                                              bottleneck_tensor)
        ground_truth = np.zeros(class_count, dtype=np.float32)
        ground_truth[label_index] = 1.0
        bottlenecks.append(bottleneck)
        ground_truths.append(ground_truth)
        filenames.append(image_name)
  return bottlenecks, ground_truths, filenames

# %% [markdown]
# The following function retrieves bottleneck values for training images, after distortions.
# If we're training with distortions like crops, scales, or flips, we have to recalculate the full model for every image, and so we can't use cached bottleneck values. Instead we find random images for the requested category, run them through the distortion graph, and then the full graph to get the bottleneck results for each.

# %%
def get_random_distorted_bottlenecks(
    sess, image_lists, how_many, category, image_dir, input_jpeg_tensor,
    distorted_image, resized_input_tensor, bottleneck_tensor):

  class_count = len(image_lists.keys())
  bottlenecks = []
  ground_truths = []
  for unused_i in range(how_many):
    label_index = random.randrange(class_count)
    label_name = list(image_lists.keys())[label_index]
    image_index = random.randrange(MAX_NUM_IMAGES_PER_CLASS + 1)
    image_path = get_image_path(image_lists, label_name, image_index, image_dir,
                                category)
    if not gfile.Exists(image_path):
      tf.logging.fatal('File does not exist %s', image_path)
    jpeg_data = gfile.FastGFile(image_path, 'rb').read()
    # Note that we materialize the distorted_image_data as a numpy array before
    # sending running inference on the image. This involves 2 memory copies and
    # might be optimized in other implementations.
    distorted_image_data = sess.run(distorted_image,
                                    {input_jpeg_tensor: jpeg_data})
    bottleneck = run_bottleneck_on_image(sess, distorted_image_data,
                                         resized_input_tensor,
                                         bottleneck_tensor)
    ground_truth = np.zeros(class_count, dtype=np.float32)
    ground_truth[label_index] = 1.0
    bottlenecks.append(bottleneck)
    ground_truths.append(ground_truth)
  return bottlenecks, ground_truths

# %%
# return whether any distortions are enabled
def should_distort_images(flip_left_right, random_crop, random_scale,
                          random_brightness):
  return (flip_left_right or (random_crop != 0) or (random_scale != 0) or
          (random_brightness != 0))

# %% [markdown]
# The following function creates the operations to apply the specified distortions.
#   During training it can help to improve the results if we run the images
#   through simple distortions like crops, scales, and flips. These reflect the
#   kind of variations we expect in the real world, and so can help train the
#   model to cope with natural data more effectively. Here we take the supplied
#   parameters and construct a network of operations to apply them to an image.

# %%
def add_input_distortions(flip_left_right, random_crop, random_scale,
                          random_brightness):
  
  jpeg_data = tf.placeholder(tf.string, name='DistortJPGInput')
  decoded_image = tf.image.decode_jpeg(jpeg_data, channels=MODEL_INPUT_DEPTH)
  decoded_image_as_float = tf.cast(decoded_image, dtype=tf.float32)
  decoded_image_4d = tf.expand_dims(decoded_image_as_float, 0)
  margin_scale = 1.0 + (random_crop / 100.0)
  resize_scale = 1.0 + (random_scale / 100.0)
  margin_scale_value = tf.constant(margin_scale)
  resize_scale_value = tf.random_uniform(tensor_shape.scalar(),
                                         minval=1.0,
                                         maxval=resize_scale)
  scale_value = tf.multiply(margin_scale_value, resize_scale_value)
  precrop_width = tf.multiply(scale_value, MODEL_INPUT_WIDTH)
  precrop_height = tf.multiply(scale_value, MODEL_INPUT_HEIGHT)
  precrop_shape = tf.stack([precrop_height, precrop_width])
  precrop_shape_as_int = tf.cast(precrop_shape, dtype=tf.int32)
  precropped_image = tf.image.resize_bilinear(decoded_image_4d,
                                              precrop_shape_as_int)
  precropped_image_3d = tf.squeeze(precropped_image, squeeze_dims=[0])
  cropped_image = tf.random_crop(precropped_image_3d,
                                 [MODEL_INPUT_HEIGHT, MODEL_INPUT_WIDTH,
                                  MODEL_INPUT_DEPTH])
  if flip_left_right:
    flipped_image = tf.image.random_flip_left_right(cropped_image)
  else:
    flipped_image = cropped_image
  brightness_min = 1.0 - (random_brightness / 100.0)
  brightness_max = 1.0 + (random_brightness / 100.0)
  brightness_value = tf.random_uniform(tensor_shape.scalar(),
                                       minval=brightness_min,
                                       maxval=brightness_max)
  brightened_image = tf.multiply(flipped_image, brightness_value)
  distort_result = tf.expand_dims(brightened_image, 0, name='DistortResult')
  return jpeg_data, distort_result

# %% [markdown]
# Attach a lot of summaries to a Tensor (for TensorBoard visualization).

# %%
def variable_summaries(var):
  
  with tf.name_scope('summaries'):
    mean = tf.reduce_mean(var)
    tf.summary.scalar('mean', mean)
    with tf.name_scope('stddev'):
      stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
    tf.summary.scalar('stddev', stddev)
    tf.summary.scalar('max', tf.reduce_max(var))
    tf.summary.scalar('min', tf.reduce_min(var))
    tf.summary.histogram('histogram', var)

# %% [markdown]
# The following function adds a new softmax and fully-connected layer for training.
#   We need to retrain the top layer to identify our new classes, so this function
#   adds the right operations to the graph, along with some variables to hold the
#   weights, and then sets up all the gradients for the backward pass.
#   The set up for the softmax and fully-connected layers is based on:
#   https://tensorflow.org/versions/master/tutorials/mnist/beginners/index.html

# %%
def add_final_training_ops(class_count, final_tensor_name, bottleneck_tensor):
  
  with tf.name_scope('input'):
    bottleneck_input = tf.placeholder_with_default(
        bottleneck_tensor, shape=[None, BOTTLENECK_TENSOR_SIZE],
        name='BottleneckInputPlaceholder')

    ground_truth_input = tf.placeholder(tf.float32,
                                        [None, class_count],
                                        name='GroundTruthInput')

  # Organizing the following ops as `final_training_ops` so they're easier
  # to see in TensorBoard
  layer_name = 'final_training_ops'
  with tf.name_scope(layer_name):
    with tf.name_scope('weights'):
      layer_weights = tf.Variable(tf.truncated_normal([BOTTLENECK_TENSOR_SIZE, class_count], stddev=0.001), name='final_weights')
      variable_summaries(layer_weights)
    with tf.name_scope('biases'):
      layer_biases = tf.Variable(tf.zeros([class_count]), name='final_biases')
      variable_summaries(layer_biases)
    with tf.name_scope('Wx_plus_b'):
      logits = tf.matmul(bottleneck_input, layer_weights) + layer_biases
      tf.summary.histogram('pre_activations', logits)

  final_tensor = tf.nn.softmax(logits, name=final_tensor_name)
  tf.summary.histogram('activations', final_tensor)

  with tf.name_scope('cross_entropy'):
    cross_entropy = tf.nn.softmax_cross_entropy_with_logits(
        labels=ground_truth_input, logits=logits)
    with tf.name_scope('total'):
      cross_entropy_mean = tf.reduce_mean(cross_entropy)
  tf.summary.scalar('cross_entropy', cross_entropy_mean)

  with tf.name_scope('train'):
    train_step = tf.train.GradientDescentOptimizer(learning_rate).minimize(
        cross_entropy_mean)

  return (train_step, cross_entropy_mean, bottleneck_input, ground_truth_input,
          final_tensor)

# %% [markdown]
# The following function inserts the operations we need to evaluate the accuracy of our results.

# %%
def add_evaluation_step(result_tensor, ground_truth_tensor):

  with tf.name_scope('accuracy'):
    with tf.name_scope('correct_prediction'):
      prediction = tf.argmax(result_tensor, 1)
      correct_prediction = tf.equal(
          prediction, tf.argmax(ground_truth_tensor, 1))
    with tf.name_scope('accuracy'):
      evaluation_step = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
  tf.summary.scalar('accuracy', evaluation_step)
  return evaluation_step, prediction

# %% [markdown]
# Main function :

# %%
# Setup the directory we'll write summaries to for TensorBoard
if tf.gfile.Exists(summaries_dir):
    tf.gfile.DeleteRecursively(summaries_dir)
tf.gfile.MakeDirs(summaries_dir)

# Set up the pre-trained graph.
maybe_download_and_extract()
graph, bottleneck_tensor, jpeg_data_tensor, resized_image_tensor = (
      create_inception_graph())

# Look at the folder structure, and create lists of all the images.
image_lists = create_image_lists(image_dir, testing_percentage,
                                   validation_percentage)
class_count = len(image_lists.keys())
if class_count == 0:
    print('No valid folders of images found at ' + image_dir)
if class_count == 1:
    print('Only one valid folder of images found at ' + image_dir +
          ' - multiple classes are needed for classification.')
# See if the command-line flags mean we're applying any distortions.
do_distort_images = should_distort_images(
      flip_left_right, random_crop, random_scale,
      random_brightness)
sess = tf.Session()

if do_distort_images:
    # We will be applying distortions, so setup the operations we'll need.
    distorted_jpeg_data_tensor, distorted_image_tensor = add_input_distortions(
        flip_left_right, random_crop, random_scale,
        random_brightness)
else:
    # We'll make sure we've calculated the 'bottleneck' image summaries and
    # cached them on disk.
    cache_bottlenecks(sess, image_lists, image_dir, bottleneck_dir,
                      jpeg_data_tensor, bottleneck_tensor)

# Add the new layer that we'll be training.
(train_step, cross_entropy, bottleneck_input, ground_truth_input,
   final_tensor) = add_final_training_ops(len(image_lists.keys()),
                                          final_tensor_name,
                                          bottleneck_tensor)

# Create the operations we need to evaluate the accuracy of our new layer.
evaluation_step, prediction = add_evaluation_step(
      final_tensor, ground_truth_input)

# Merge all the summaries and write them out to /tmp/retrain_logs (by default)
merged = tf.summary.merge_all()
train_writer = tf.summary.FileWriter(summaries_dir + '/train',sess.graph)
validation_writer = tf.summary.FileWriter(summaries_dir + '/validation')

# Set up all our weights to their initial default values.
init = tf.global_variables_initializer()
sess.run(init)

# Run the training for as many cycles as requested on the command line.
for i in range(how_many_training_steps):
    # Get a batch of input bottleneck values, either calculated fresh every time
    # with distortions applied, or from the cache stored on disk.
    if do_distort_images:
        train_bottlenecks, train_ground_truth = get_random_distorted_bottlenecks(
            sess, image_lists, train_batch_size, 'training',
            image_dir, distorted_jpeg_data_tensor,
            distorted_image_tensor, resized_image_tensor, bottleneck_tensor)
    else:
        train_bottlenecks, train_ground_truth, _ = get_random_cached_bottlenecks(
            sess, image_lists, train_batch_size, 'training',
            bottleneck_dir, image_dir, jpeg_data_tensor,
            bottleneck_tensor)
    # Feed the bottlenecks and ground truth into the graph, and run a training
    # step. Capture training summaries for TensorBoard with the `merged` op.
    train_summary, _ = sess.run([merged, train_step],
                                feed_dict={bottleneck_input: train_bottlenecks,
                                           ground_truth_input: train_ground_truth})
    train_writer.add_summary(train_summary, i)

    # Every so often, print out how well the graph is training.
    is_last_step = (i + 1 == how_many_training_steps)
    if (i % eval_step_interval) == 0 or is_last_step:
        train_accuracy, cross_entropy_value = sess.run(
            [evaluation_step, cross_entropy],
            feed_dict={bottleneck_input: train_bottlenecks,
                       ground_truth_input: train_ground_truth})
        print('%s: Step %d: Train accuracy = %.1f%%' % (datetime.now(), i,
                                                      train_accuracy * 100))
        print('%s: Step %d: Cross entropy = %f' % (datetime.now(), i,
                                                 cross_entropy_value))
        validation_bottlenecks, validation_ground_truth, _ = (
            get_random_cached_bottlenecks(
                sess, image_lists, validation_batch_size, 'validation',
                bottleneck_dir, image_dir, jpeg_data_tensor,
                bottleneck_tensor))
        # Run a validation step and capture training summaries for TensorBoard
        # with the `merged` op.
        validation_summary, validation_accuracy = sess.run(
            [merged, evaluation_step],
            feed_dict={bottleneck_input: validation_bottlenecks,
                     ground_truth_input: validation_ground_truth})
        validation_writer.add_summary(validation_summary, i)
        print('%s: Step %d: Validation accuracy = %.1f%% (N=%d)' %
              (datetime.now(), i, validation_accuracy * 100,
               len(validation_bottlenecks)))

# We've completed all our training, so run a final test evaluation on
# some new images we haven't used before.
test_bottlenecks, test_ground_truth, test_filenames = (
    get_random_cached_bottlenecks(sess, image_lists, test_batch_size,
                                  'testing', bottleneck_dir,
                                  image_dir, jpeg_data_tensor,
                                  bottleneck_tensor))
test_accuracy, predictions = sess.run(
    [evaluation_step, prediction],
    feed_dict={bottleneck_input: test_bottlenecks,
               ground_truth_input: test_ground_truth})
print('Final test accuracy = %.1f%% (N=%d)' % (
    test_accuracy * 100, len(test_bottlenecks)))

if print_misclassified_test_images:
    print('=== MISCLASSIFIED TEST IMAGES ===')
    for i, test_filename in enumerate(test_filenames):
        if predictions[i] != test_ground_truth[i].argmax():
            print('%70s  %s' % (test_filename, image_lists.keys()[predictions[i]]))

# Write out the trained graph and labels with the weights stored as constants.
output_graph_def = graph_util.convert_variables_to_constants(
    sess, graph.as_graph_def(), [final_tensor_name])
with gfile.FastGFile(output_graph, 'wb') as f:
    f.write(output_graph_def.SerializeToString())
with gfile.FastGFile(output_labels, 'w') as f:
    f.write('\n'.join(image_lists.keys()) + '\n')
# Out:
# Looking for images in 'Cat'
# Looking for images in 'Dog'
# Creating bottleneck at bottlenecks\Cat\cat.0.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.10.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.100.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.101.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.102.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.103.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.104.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.105.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.107.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.108.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.109.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.11.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.110.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.113.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.115.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.116.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.118.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.119.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.12.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.120.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.122.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.123.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.124.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.125.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.126.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.127.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.129.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.13.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.130.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.131.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.132.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.136.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.137.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.138.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.139.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.140.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.141.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.142.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.143.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.144.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.145.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.146.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.149.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.150.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.151.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.152.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.153.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.154.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.155.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.156.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.157.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.158.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.159.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.16.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.160.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.161.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.162.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.163.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.164.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.165.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.167.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.168.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.169.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.17.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.170.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.171.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.173.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.174.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.175.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.176.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.177.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.178.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.179.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.18.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.180.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.181.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.182.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.185.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.186.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.187.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.188.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.19.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.190.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.191.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.193.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.194.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.195.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.196.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.197.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.198.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.199.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.2.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.20.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.201.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.202.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.203.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.204.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.206.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.207.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.208.jpg.txt
# 100 bottleneck files created.
# Creating bottleneck at bottlenecks\Cat\cat.209.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.21.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.210.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.212.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.215.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.216.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.218.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.219.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.22.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.220.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.221.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.222.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.223.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.224.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.225.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.226.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.228.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.229.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.230.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.231.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.232.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.233.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.234.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.235.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.236.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.238.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.239.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.240.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.241.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.242.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.243.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.244.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.245.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.248.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.249.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.25.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.250.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.251.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.252.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.253.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.254.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.255.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.256.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.258.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.259.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.26.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.260.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.261.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.262.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.263.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.264.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.265.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.266.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.268.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.269.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.27.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.271.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.273.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.274.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.275.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.276.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.277.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.279.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.28.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.280.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.281.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.286.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.287.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.288.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.289.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.29.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.290.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.291.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.292.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.293.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.294.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.297.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.299.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.3.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.30.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.300.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.301.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.302.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.303.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.304.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.305.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.308.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.309.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.310.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.311.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.312.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.315.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.316.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.317.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.318.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.319.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.32.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.322.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.323.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.324.jpg.txt
# 200 bottleneck files created.
# Creating bottleneck at bottlenecks\Cat\cat.326.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.327.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.328.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.329.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.33.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.330.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.332.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.334.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.337.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.338.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.339.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.34.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.340.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.342.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.343.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.344.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.345.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.346.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.347.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.349.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.35.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.350.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.351.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.352.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.353.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.354.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.355.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.357.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.358.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.359.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.360.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.361.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.362.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.363.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.366.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.367.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.368.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.369.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.37.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.370.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.371.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.372.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.373.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.374.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.376.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.377.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.378.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.38.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.381.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.382.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.383.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.384.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.386.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.389.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.39.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.390.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.391.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.392.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.393.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.397.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.398.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.40.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.400.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.401.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.402.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.403.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.404.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.406.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.407.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.409.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.414.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.415.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.416.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.417.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.418.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.419.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.42.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.420.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.421.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.422.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.423.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.424.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.425.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.426.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.427.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.428.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.43.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.430.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.431.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.432.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.436.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.437.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.439.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.44.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.440.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.441.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.443.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.444.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.445.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.446.jpg.txt
# 300 bottleneck files created.
# Creating bottleneck at bottlenecks\Cat\cat.447.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.448.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.449.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.45.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.450.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.451.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.452.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.453.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.454.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.455.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.456.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.459.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.460.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.461.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.462.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.463.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.464.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.467.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.469.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.47.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.471.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.472.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.474.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.475.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.476.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.477.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.478.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.479.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.48.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.483.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.484.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.486.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.487.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.488.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.489.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.49.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.491.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.492.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.493.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.494.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.496.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.497.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.498.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.499.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.5.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.50.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.500.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.501.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.502.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.503.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.504.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.505.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.506.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.507.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.509.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.51.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.511.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.512.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.513.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.514.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.516.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.517.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.518.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.519.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.52.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.520.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.521.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.523.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.524.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.526.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.527.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.528.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.529.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.531.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.532.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.533.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.534.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.535.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.536.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.537.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.538.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.539.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.54.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.540.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.541.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.542.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.543.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.544.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.545.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.546.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.548.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.549.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.55.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.550.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.551.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.552.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.553.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.554.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.555.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.556.jpg.txt
# 400 bottleneck files created.
# Creating bottleneck at bottlenecks\Cat\cat.558.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.56.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.560.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.561.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.564.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.566.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.567.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.568.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.570.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.572.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.573.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.574.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.576.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.578.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.579.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.58.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.581.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.585.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.586.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.587.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.588.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.59.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.590.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.591.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.592.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.593.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.594.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.595.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.597.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.598.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.599.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.6.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.60.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.600.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.601.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.602.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.604.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.606.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.607.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.608.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.609.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.610.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.611.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.612.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.613.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.614.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.615.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.618.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.619.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.62.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.620.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.621.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.622.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.623.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.624.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.625.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.626.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.627.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.63.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.630.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.631.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.632.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.633.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.634.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.635.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.636.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.638.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.639.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.640.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.641.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.643.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.644.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.645.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.646.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.648.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.649.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.650.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.652.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.653.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.654.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.656.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.658.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.659.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.66.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.660.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.661.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.662.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.663.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.665.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.666.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.667.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.668.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.669.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.672.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.674.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.675.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.676.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.678.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.679.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.680.jpg.txt
# 500 bottleneck files created.
# Creating bottleneck at bottlenecks\Cat\cat.681.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.682.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.683.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.684.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.685.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.686.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.688.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.689.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.69.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.690.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.691.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.692.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.693.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.695.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.696.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.698.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.7.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.70.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.700.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.702.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.703.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.704.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.706.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.707.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.708.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.709.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.71.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.710.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.711.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.712.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.713.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.714.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.715.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.716.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.718.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.72.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.720.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.721.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.722.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.723.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.724.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.725.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.726.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.727.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.729.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.73.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.731.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.733.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.735.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.737.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.738.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.739.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.74.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.740.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.741.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.743.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.744.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.745.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.746.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.747.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.748.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.749.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.75.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.750.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.751.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.752.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.753.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.754.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.755.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.757.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.758.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.759.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.76.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.760.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.761.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.763.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.764.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.765.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.766.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.767.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.768.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.769.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.77.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.770.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.771.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.773.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.774.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.776.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.777.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.778.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.779.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.780.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.781.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.783.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.784.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.785.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.786.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.787.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.788.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.789.jpg.txt
# 600 bottleneck files created.
# Creating bottleneck at bottlenecks\Cat\cat.79.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.790.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.792.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.794.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.795.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.796.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.797.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.798.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.8.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.80.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.801.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.802.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.804.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.805.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.806.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.808.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.809.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.810.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.811.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.812.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.814.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.815.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.817.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.818.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.82.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.820.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.821.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.822.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.823.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.824.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.825.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.826.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.827.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.828.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.829.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.83.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.830.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.831.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.832.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.833.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.835.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.836.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.837.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.84.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.840.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.841.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.842.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.843.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.844.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.845.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.848.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.849.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.85.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.851.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.852.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.853.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.854.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.856.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.857.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.858.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.859.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.86.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.860.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.861.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.862.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.863.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.864.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.865.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.866.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.867.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.868.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.869.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.87.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.870.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.871.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.872.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.873.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.874.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.875.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.876.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.878.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.879.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.88.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.880.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.882.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.883.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.884.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.886.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.888.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.889.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.89.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.890.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.891.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.892.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.894.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.895.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.896.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.897.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.898.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.899.jpg.txt
# 700 bottleneck files created.
# Creating bottleneck at bottlenecks\Cat\cat.9.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.90.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.900.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.903.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.905.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.906.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.907.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.908.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.909.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.910.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.912.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.913.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.914.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.915.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.917.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.919.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.92.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.920.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.921.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.922.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.925.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.926.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.927.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.928.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.929.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.93.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.930.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.931.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.932.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.933.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.934.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.935.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.937.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.938.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.939.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.940.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.941.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.942.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.943.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.944.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.945.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.946.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.947.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.948.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.95.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.950.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.951.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.952.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.954.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.955.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.956.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.957.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.958.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.959.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.96.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.960.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.961.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.962.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.963.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.964.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.965.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.966.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.967.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.968.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.97.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.970.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.971.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.972.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.973.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.974.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.975.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.976.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.978.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.979.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.98.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.981.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.983.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.984.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.985.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.987.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.988.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.99.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.990.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.991.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.992.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.993.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.994.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.995.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.997.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.998.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.999.jpg.txt
# 800 bottleneck files created.
# 900 bottleneck files created.
# 1000 bottleneck files created.
# 1100 bottleneck files created.
# 1200 bottleneck files created.
# 1300 bottleneck files created.
# 1400 bottleneck files created.
# 1500 bottleneck files created.
# Creating bottleneck at bottlenecks\Cat\cat.1.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.112.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.114.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.133.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.134.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.14.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.147.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.148.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.15.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.166.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.172.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.183.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.184.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.189.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.192.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.211.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.214.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.217.jpg.txt
# 1600 bottleneck files created.
# Creating bottleneck at bottlenecks\Cat\cat.227.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.23.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.246.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.257.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.267.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.270.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.272.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.284.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.295.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.296.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.306.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.313.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.314.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.321.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.331.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.335.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.336.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.356.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.364.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.379.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.396.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.399.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.405.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.408.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.411.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.412.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.413.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.435.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.442.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.46.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.466.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.470.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.473.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.481.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.495.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.508.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.525.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.53.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.559.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.563.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.565.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.57.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.571.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.575.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.577.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.582.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.583.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.589.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.596.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.603.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.61.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.616.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.628.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.637.jpg.txt
# Creating bottleneck at bottlenecks\Cat\cat.64.jpg.txt
# ...
# 2017-11-15 10:02:53.906605: Step 3220: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:02:55.222192: Step 3230: Train accuracy = 100.0%
# 2017-11-15 10:02:55.222192: Step 3230: Cross entropy = 0.007723
# 2017-11-15 10:02:55.381670: Step 3230: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:02:56.512312: Step 3240: Train accuracy = 100.0%
# 2017-11-15 10:02:56.512312: Step 3240: Cross entropy = 0.004194
# 2017-11-15 10:02:56.624415: Step 3240: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:02:57.672162: Step 3250: Train accuracy = 100.0%
# 2017-11-15 10:02:57.672162: Step 3250: Cross entropy = 0.007298
# 2017-11-15 10:02:57.782441: Step 3250: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:02:58.902214: Step 3260: Train accuracy = 100.0%
# 2017-11-15 10:02:58.903219: Step 3260: Cross entropy = 0.004932
# 2017-11-15 10:02:59.036578: Step 3260: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:00.179221: Step 3270: Train accuracy = 100.0%
# 2017-11-15 10:03:00.179221: Step 3270: Cross entropy = 0.003533
# 2017-11-15 10:03:00.279290: Step 3270: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:01.316801: Step 3280: Train accuracy = 100.0%
# 2017-11-15 10:03:01.316801: Step 3280: Cross entropy = 0.008866
# 2017-11-15 10:03:01.416917: Step 3280: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:03:02.391412: Step 3290: Train accuracy = 100.0%
# 2017-11-15 10:03:02.391412: Step 3290: Cross entropy = 0.010735
# 2017-11-15 10:03:02.470991: Step 3290: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:03:03.499086: Step 3300: Train accuracy = 100.0%
# 2017-11-15 10:03:03.499587: Step 3300: Cross entropy = 0.004707
# 2017-11-15 10:03:03.599535: Step 3300: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:04.645291: Step 3310: Train accuracy = 100.0%
# 2017-11-15 10:03:04.645291: Step 3310: Cross entropy = 0.006790
# 2017-11-15 10:03:04.742062: Step 3310: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:05.693995: Step 3320: Train accuracy = 100.0%
# 2017-11-15 10:03:05.693995: Step 3320: Cross entropy = 0.004933
# 2017-11-15 10:03:05.776992: Step 3320: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:03:06.777803: Step 3330: Train accuracy = 100.0%
# 2017-11-15 10:03:06.777803: Step 3330: Cross entropy = 0.006350
# 2017-11-15 10:03:06.878104: Step 3330: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:07.831283: Step 3340: Train accuracy = 100.0%
# 2017-11-15 10:03:07.831283: Step 3340: Cross entropy = 0.004889
# 2017-11-15 10:03:07.928400: Step 3340: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:03:08.899533: Step 3350: Train accuracy = 100.0%
# 2017-11-15 10:03:08.899533: Step 3350: Cross entropy = 0.006232
# 2017-11-15 10:03:08.979389: Step 3350: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:03:10.016885: Step 3360: Train accuracy = 100.0%
# 2017-11-15 10:03:10.016885: Step 3360: Cross entropy = 0.006493
# 2017-11-15 10:03:10.131834: Step 3360: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:03:11.165725: Step 3370: Train accuracy = 100.0%
# 2017-11-15 10:03:11.165725: Step 3370: Cross entropy = 0.007022
# 2017-11-15 10:03:11.270532: Step 3370: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:12.285759: Step 3380: Train accuracy = 100.0%
# 2017-11-15 10:03:12.285759: Step 3380: Cross entropy = 0.008128
# 2017-11-15 10:03:12.385983: Step 3380: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:03:13.334619: Step 3390: Train accuracy = 100.0%
# 2017-11-15 10:03:13.334619: Step 3390: Cross entropy = 0.004799
# 2017-11-15 10:03:13.434806: Step 3390: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:03:14.421114: Step 3400: Train accuracy = 100.0%
# 2017-11-15 10:03:14.436724: Step 3400: Cross entropy = 0.005355
# 2017-11-15 10:03:14.520995: Step 3400: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:15.486180: Step 3410: Train accuracy = 100.0%
# 2017-11-15 10:03:15.486180: Step 3410: Cross entropy = 0.007402
# 2017-11-15 10:03:15.595653: Step 3410: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:16.623850: Step 3420: Train accuracy = 100.0%
# 2017-11-15 10:03:16.623850: Step 3420: Cross entropy = 0.003188
# 2017-11-15 10:03:16.718961: Step 3420: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:03:17.672843: Step 3430: Train accuracy = 99.0%
# 2017-11-15 10:03:17.672843: Step 3430: Cross entropy = 0.022651
# 2017-11-15 10:03:17.773141: Step 3430: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:03:18.725231: Step 3440: Train accuracy = 100.0%
# 2017-11-15 10:03:18.725231: Step 3440: Cross entropy = 0.003952
# 2017-11-15 10:03:18.809887: Step 3440: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:19.843179: Step 3450: Train accuracy = 100.0%
# 2017-11-15 10:03:19.843179: Step 3450: Cross entropy = 0.009964
# 2017-11-15 10:03:19.942480: Step 3450: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:21.009532: Step 3460: Train accuracy = 99.0%
# 2017-11-15 10:03:21.009532: Step 3460: Cross entropy = 0.021157
# 2017-11-15 10:03:21.113774: Step 3460: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:22.162619: Step 3470: Train accuracy = 99.0%
# 2017-11-15 10:03:22.162619: Step 3470: Cross entropy = 0.024534
# 2017-11-15 10:03:22.256935: Step 3470: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:23.224253: Step 3480: Train accuracy = 99.0%
# 2017-11-15 10:03:23.224253: Step 3480: Cross entropy = 0.021802
# 2017-11-15 10:03:23.324590: Step 3480: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:03:24.347169: Step 3490: Train accuracy = 100.0%
# 2017-11-15 10:03:24.347169: Step 3490: Cross entropy = 0.004956
# 2017-11-15 10:03:24.447927: Step 3490: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:25.413516: Step 3500: Train accuracy = 100.0%
# 2017-11-15 10:03:25.413516: Step 3500: Cross entropy = 0.007102
# 2017-11-15 10:03:25.513372: Step 3500: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:26.467472: Step 3510: Train accuracy = 100.0%
# 2017-11-15 10:03:26.467472: Step 3510: Cross entropy = 0.004598
# 2017-11-15 10:03:26.567809: Step 3510: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:03:27.622024: Step 3520: Train accuracy = 100.0%
# 2017-11-15 10:03:27.622024: Step 3520: Cross entropy = 0.004704
# 2017-11-15 10:03:27.725495: Step 3520: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:28.777390: Step 3530: Train accuracy = 100.0%
# 2017-11-15 10:03:28.777390: Step 3530: Cross entropy = 0.006368
# 2017-11-15 10:03:28.899494: Step 3530: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:29.949951: Step 3540: Train accuracy = 100.0%
# 2017-11-15 10:03:29.949951: Step 3540: Cross entropy = 0.005975
# 2017-11-15 10:03:30.061137: Step 3540: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:03:31.063903: Step 3550: Train accuracy = 100.0%
# 2017-11-15 10:03:31.064406: Step 3550: Cross entropy = 0.006557
# 2017-11-15 10:03:31.148617: Step 3550: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:32.121340: Step 3560: Train accuracy = 100.0%
# 2017-11-15 10:03:32.121340: Step 3560: Cross entropy = 0.003604
# 2017-11-15 10:03:32.203563: Step 3560: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:03:33.194008: Step 3570: Train accuracy = 100.0%
# 2017-11-15 10:03:33.194008: Step 3570: Cross entropy = 0.005916
# 2017-11-15 10:03:33.295328: Step 3570: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:34.322798: Step 3580: Train accuracy = 100.0%
# 2017-11-15 10:03:34.322798: Step 3580: Cross entropy = 0.004781
# 2017-11-15 10:03:34.441310: Step 3580: Validation accuracy = 96.0% (N=100)
# 2017-11-15 10:03:35.444433: Step 3590: Train accuracy = 100.0%
# 2017-11-15 10:03:35.444433: Step 3590: Cross entropy = 0.003527
# 2017-11-15 10:03:35.560300: Step 3590: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:03:36.546784: Step 3600: Train accuracy = 99.0%
# 2017-11-15 10:03:36.546784: Step 3600: Cross entropy = 0.020020
# 2017-11-15 10:03:36.662253: Step 3600: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:37.680452: Step 3610: Train accuracy = 100.0%
# 2017-11-15 10:03:37.680452: Step 3610: Cross entropy = 0.007248
# 2017-11-15 10:03:37.780760: Step 3610: Validation accuracy = 98.0% (N=100)
# 2017-11-15 10:03:38.764873: Step 3620: Train accuracy = 100.0%
# 2017-11-15 10:03:38.764873: Step 3620: Cross entropy = 0.005629
# 2017-11-15 10:03:38.849422: Step 3620: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:39.835600: Step 3630: Train accuracy = 100.0%
# 2017-11-15 10:03:39.835600: Step 3630: Cross entropy = 0.009188
# 2017-11-15 10:03:39.915748: Step 3630: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:40.880097: Step 3640: Train accuracy = 100.0%
# 2017-11-15 10:03:40.880097: Step 3640: Cross entropy = 0.003321
# 2017-11-15 10:03:40.964251: Step 3640: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:03:42.003934: Step 3650: Train accuracy = 100.0%
# 2017-11-15 10:03:42.003934: Step 3650: Cross entropy = 0.009746
# 2017-11-15 10:03:42.108308: Step 3650: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:03:43.105137: Step 3660: Train accuracy = 100.0%
# 2017-11-15 10:03:43.105137: Step 3660: Cross entropy = 0.004559
# 2017-11-15 10:03:43.190342: Step 3660: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:44.192195: Step 3670: Train accuracy = 100.0%
# 2017-11-15 10:03:44.192195: Step 3670: Cross entropy = 0.010627
# 2017-11-15 10:03:44.292197: Step 3670: Validation accuracy = 98.0% (N=100)
# 2017-11-15 10:03:45.229699: Step 3680: Train accuracy = 100.0%
# 2017-11-15 10:03:45.229699: Step 3680: Cross entropy = 0.002066
# 2017-11-15 10:03:45.330186: Step 3680: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:03:46.311648: Step 3690: Train accuracy = 100.0%
# 2017-11-15 10:03:46.311648: Step 3690: Cross entropy = 0.002835
# 2017-11-15 10:03:46.411548: Step 3690: Validation accuracy = 97.0% (N=100)
# 2017-11-15 10:03:47.397940: Step 3700: Train accuracy = 100.0%
# 2017-11-15 10:03:47.397940: Step 3700: Cross entropy = 0.005361
# 2017-11-15 10:03:47.498179: Step 3700: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:48.530025: Step 3710: Train accuracy = 100.0%
# 2017-11-15 10:03:48.530025: Step 3710: Cross entropy = 0.004752
# 2017-11-15 10:03:48.646037: Step 3710: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:49.632612: Step 3720: Train accuracy = 100.0%
# 2017-11-15 10:03:49.632612: Step 3720: Cross entropy = 0.005092
# 2017-11-15 10:03:49.721721: Step 3720: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:03:50.664583: Step 3730: Train accuracy = 100.0%
# 2017-11-15 10:03:50.664583: Step 3730: Cross entropy = 0.003006
# 2017-11-15 10:03:50.767172: Step 3730: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:51.726139: Step 3740: Train accuracy = 100.0%
# 2017-11-15 10:03:51.726139: Step 3740: Cross entropy = 0.004187
# 2017-11-15 10:03:51.820957: Step 3740: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:52.758402: Step 3750: Train accuracy = 100.0%
# 2017-11-15 10:03:52.758402: Step 3750: Cross entropy = 0.004904
# 2017-11-15 10:03:52.838544: Step 3750: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:53.791713: Step 3760: Train accuracy = 100.0%
# 2017-11-15 10:03:53.791713: Step 3760: Cross entropy = 0.002036
# 2017-11-15 10:03:53.891989: Step 3760: Validation accuracy = 98.0% (N=100)
# 2017-11-15 10:03:54.857783: Step 3770: Train accuracy = 100.0%
# 2017-11-15 10:03:54.857783: Step 3770: Cross entropy = 0.007918
# 2017-11-15 10:03:54.949114: Step 3770: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:03:55.912763: Step 3780: Train accuracy = 100.0%
# 2017-11-15 10:03:55.912763: Step 3780: Cross entropy = 0.007527
# 2017-11-15 10:03:56.013428: Step 3780: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:56.977712: Step 3790: Train accuracy = 100.0%
# 2017-11-15 10:03:56.977712: Step 3790: Cross entropy = 0.004105
# 2017-11-15 10:03:57.077788: Step 3790: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:03:58.017016: Step 3800: Train accuracy = 100.0%
# 2017-11-15 10:03:58.017016: Step 3800: Cross entropy = 0.004484
# 2017-11-15 10:03:58.099547: Step 3800: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:03:59.069258: Step 3810: Train accuracy = 100.0%
# 2017-11-15 10:03:59.069258: Step 3810: Cross entropy = 0.007393
# 2017-11-15 10:03:59.169693: Step 3810: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:04:00.166522: Step 3820: Train accuracy = 100.0%
# 2017-11-15 10:04:00.166522: Step 3820: Cross entropy = 0.007225
# 2017-11-15 10:04:00.267102: Step 3820: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:04:01.252734: Step 3830: Train accuracy = 100.0%
# 2017-11-15 10:04:01.252734: Step 3830: Cross entropy = 0.005583
# 2017-11-15 10:04:01.352976: Step 3830: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:04:02.339320: Step 3840: Train accuracy = 100.0%
# 2017-11-15 10:04:02.339320: Step 3840: Cross entropy = 0.006154
# 2017-11-15 10:04:02.439836: Step 3840: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:04:03.503705: Step 3850: Train accuracy = 100.0%
# 2017-11-15 10:04:03.503705: Step 3850: Cross entropy = 0.003721
# 2017-11-15 10:04:03.603406: Step 3850: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:04:04.626896: Step 3860: Train accuracy = 100.0%
# 2017-11-15 10:04:04.626896: Step 3860: Cross entropy = 0.004108
# 2017-11-15 10:04:04.742362: Step 3860: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:04:05.774817: Step 3870: Train accuracy = 100.0%
# 2017-11-15 10:04:05.774817: Step 3870: Cross entropy = 0.003787
# 2017-11-15 10:04:05.882160: Step 3870: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:04:06.912662: Step 3880: Train accuracy = 100.0%
# 2017-11-15 10:04:06.912662: Step 3880: Cross entropy = 0.007083
# 2017-11-15 10:04:07.012417: Step 3880: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:04:07.998926: Step 3890: Train accuracy = 100.0%
# 2017-11-15 10:04:07.998926: Step 3890: Cross entropy = 0.006881
# 2017-11-15 10:04:08.083581: Step 3890: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:04:09.101339: Step 3900: Train accuracy = 100.0%
# 2017-11-15 10:04:09.101339: Step 3900: Cross entropy = 0.004706
# 2017-11-15 10:04:09.220862: Step 3900: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:04:10.287641: Step 3910: Train accuracy = 100.0%
# 2017-11-15 10:04:10.287641: Step 3910: Cross entropy = 0.009589
# 2017-11-15 10:04:10.387326: Step 3910: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:04:11.397581: Step 3920: Train accuracy = 100.0%
# 2017-11-15 10:04:11.397581: Step 3920: Cross entropy = 0.003636
# 2017-11-15 10:04:11.498877: Step 3920: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:04:12.570200: Step 3930: Train accuracy = 100.0%
# 2017-11-15 10:04:12.570200: Step 3930: Cross entropy = 0.003529
# 2017-11-15 10:04:12.679518: Step 3930: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:04:13.700709: Step 3940: Train accuracy = 100.0%
# 2017-11-15 10:04:13.700709: Step 3940: Cross entropy = 0.005459
# 2017-11-15 10:04:13.817934: Step 3940: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:04:14.854093: Step 3950: Train accuracy = 100.0%
# 2017-11-15 10:04:14.854093: Step 3950: Cross entropy = 0.006851
# 2017-11-15 10:04:14.960115: Step 3950: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:04:15.936425: Step 3960: Train accuracy = 100.0%
# 2017-11-15 10:04:15.936425: Step 3960: Cross entropy = 0.004295
# 2017-11-15 10:04:16.021133: Step 3960: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:04:16.992696: Step 3970: Train accuracy = 100.0%
# 2017-11-15 10:04:16.992696: Step 3970: Cross entropy = 0.005780
# 2017-11-15 10:04:17.091528: Step 3970: Validation accuracy = 99.0% (N=100)
# 2017-11-15 10:04:18.161335: Step 3980: Train accuracy = 100.0%
# 2017-11-15 10:04:18.161335: Step 3980: Cross entropy = 0.006316
# 2017-11-15 10:04:18.261341: Step 3980: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:04:19.249485: Step 3990: Train accuracy = 100.0%
# 2017-11-15 10:04:19.249485: Step 3990: Cross entropy = 0.004275
# 2017-11-15 10:04:19.332025: Step 3990: Validation accuracy = 100.0% (N=100)
# 2017-11-15 10:04:20.211176: Step 3999: Train accuracy = 100.0%
# 2017-11-15 10:04:20.211176: Step 3999: Cross entropy = 0.012711
# 2017-11-15 10:04:20.328199: Step 3999: Validation accuracy = 100.0% (N=100)
# Final test accuracy = 99.1% (N=434)
# INFO:tensorflow:Froze 2 variables.
# Converted 2 variables to const ops.

# %%
# visualize with TensorBoard
# !tensorboard --logdir=temp

# %% [markdown]
# ## Summary
#
# The final test accuracy is almost 99%  for our two classes Cat and Dog which is quite substantial given our training set contained approxiamtely only 1000 images for each classes.
#
# This is where Transfer Learning really shines. All we did was use the trained Inception Model which already had learned basic features of lines, shapes and other features that increase in abstraction as we move towards the final layers of the model.
#
# We basically retrained the last layers where we supplied training images of Cats and Dogs and the model using its pre-learnt features could "learn" the features specific to these classes and hence resulted in an impressive classification accuracy of 99%.

# %% [markdown]
# ## Exercise : Try your own ideas
#
# The whole training regime here is based on the way the image directories are structured. So building your own example shouldn't be very difficult.
#
# Suppose you wanted to classify Cheetah and Tiger:
# * Create directories for Cheetah and Tiger
# * The images will be automatically resized so that their smallest dimension is 299, and then a square 'crop' area taken from their centers (since ImageNet networks are typically tuned to answering on 299x299 images)
# * Test images should be put in the test_images directory
# * Finally, re-run everything - checking that the training images are read in correctly, that there are no errors along the way, and that (finally) the class predictions on the test set come out as expected.

# %% [markdown]
# *The code in this notebook is inspired by Github codes that can be found [here](https://github.com/Aniruddha-Tapas/Transfer-Learning-for-Animal-Classification-in-Tensorflow).
